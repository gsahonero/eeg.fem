# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from scipy.stats import uniform
import joblib as jb

# %%
path = 'D:/Github/eeg.fem/public/data/Musical/5956733/All_Data/'
df = np.genfromtxt(str(path)+'ALL.csv',delimiter=',')
print(df.shape)
X = df[:,:df.shape[1]-1]
y = df[:,df.shape[1]-1]
 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=3, test_size=0.3)
# Out:
# (6728, 2690)

# %%
iterations = range(100000, 1000000, 20000)
iter_scores = []
for i in iterations:
  classifier = SVC(C=3, kernel='rbf', gamma=i, tol=1e-3, 
                    max_iter=i ,decision_function_shape='ovr')
  scores = cross_val_score(classifier, X_train, y_train, cv=8, scoring='accuracy')
  iter_scores.append(scores.mean())

plt.plot(gamma_range, svm_scores)
plt.xlabel("Value of iterations in SVC")
plt.ylabel('Cross-Validated Accuracy')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d8976c9f6259> in <module>()
#       7   iter_scores.append(scores.mean())
#       8
# ----> 9 plt.plot(gamma_range, svm_scores)
#      10 plt.xlabel("Value of iterations in SVC")
#      11 plt.ylabel('Cross-Validated Accuracy')
#
# NameError: name 'gamma_range' is not defined

# %%
plt.plot(iterations, iter_scores)
plt.xlabel("Value of iterations in SVC")
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0,0.5,'Cross-Validated Accuracy')

# %%
classifier = SVC(kernel='rbf', max_iter=-1 ,decision_function_shape='ovr')
params = {'C': [1*10^-5, 1*10^-4, 1*10^-3, 1*10^-2, 1*10^-1, 1, 1*10^1, 1*10^2, 1*10^3, 1*10^4, 1*10^5],
          'gamma': [1*10^-5, 1*10^-4, 1*10^-3, 1*10^-2, 1*10^-1, 1, 1*10^1, 1*10^2, 1*10^3, 1*10^4, 1*10^5]}
rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=121)
rs.fit(X_train, y_train)
pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','mean_test_score']]
# Out:
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: C <= 0
#
#   FitFailedWarning)
# ...
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: gamma < 0
#
#   FitFailedWarning)

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

# %%
path = 'D:/Github/eeg.fem/public/data/Musical/5956733/All_Data/'
df = np.genfromtxt(str(path)+'ALL.csv',delimiter=',')

X = df[:,:df.shape[1]-1]
y = df[:,df.shape[1]-1]
 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=3, test_size=0.3)

# %%
classifier = SVC(kernel='rbf', max_iter=-1 ,decision_function_shape='ovr', tol=1e-3)
#classifier = SVC(C=4, kernel='rbf', gamma='scale', tol=1e-3, max_iter=-1, decision_function_shape='ovr')

params = {'C': [0.1, 1, 2, 3, 4],
          'gamma': [0.0001, 'scale']}

rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=5)

rs.fit(X_train, y_train)

pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','mean_test_score']]
# Out:
#   param_C param_gamma  mean_test_score
# 0     0.1      0.0001         0.270121
# 1       4      0.0001         0.311319
# 2       1      0.0001         0.306647
# 3       2       scale         0.409635
# 4     0.1       scale         0.319384

# %%
classifier = SVC(kernel='rbf', max_iter=-1 ,decision_function_shape='ovr', tol=1e-3)
#classifier = SVC(C=4, kernel='rbf', gamma='scale', tol=1e-3, max_iter=-1, decision_function_shape='ovr')

params = {'C': [4, 50, 100],
          'gamma': ['scale']}

rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=3)

rs.fit(X_train, y_train)

pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','mean_test_score']]
# Out:
#   param_C param_gamma  mean_test_score
# 0       4       scale         0.418765
# 1      50       scale         0.419831
# 2     100       scale         0.419831

# %%
classifier = SVC(kernel='rbf', max_iter=-1 ,decision_function_shape='ovr', tol=1e-3)
#classifier = SVC(C=4, kernel='rbf', gamma='scale', tol=1e-3, max_iter=-1, decision_function_shape='ovr')

params = {'C': [1000, 10000],
          'gamma': ['scale']}

rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=2)

rs.fit(X_train, y_train)

pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','mean_test_score']]
# Out:
#   param_C param_gamma  mean_test_score
# 0    1000       scale         0.419831
# 1   10000       scale         0.419831
