# %%
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
import pandas as pd

# %%
df = np.genfromtxt('D:/Github/eeg.fem/public/data/Musical/5956733/All_Data/ALL_Spectral density_64.csv',delimiter=',')
x = df[:, :-1]
y = df[:, -1]
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=3, test_size=0.3)

# %%
classifier = SVC(kernel='rbf', max_iter=-1 ,decision_function_shape='ovr', tol=1e-3)
#classifier = SVC(C=4, kernel='rbf', gamma='scale', tol=1e-3, max_iter=-1, decision_function_shape='ovr')

params = {'C': [0.1, 1, 2, 3, 4],
          'gamma': [0.0001, 'scale']}

rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=5)

rs.fit(X_train, y_train)

pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','mean_test_score']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-02b3603fa812> in <module>()
#       9 rs.fit(X_train, y_train)
#      10
# ---> 11 pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','mean_test_score']]
#
# NameError: name 'pd' is not defined

# %%
pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','mean_test_score']]
# Out:
#   param_C param_gamma  mean_test_score
# 0     0.1      0.0001         0.365470
# 1     0.1       scale         0.605009
# 2       1      0.0001         0.365470
# 3       2       scale         0.734763
# 4       3      0.0001         0.365470

# %%
classifier = SVC(kernel='rbf', max_iter=-1 ,decision_function_shape='ovr', tol=1e-3)
#classifier = SVC(C=4, kernel='rbf', gamma='scale', tol=1e-3, max_iter=-1, decision_function_shape='ovr')

params = {'C': [0.1, 1, 2, 3, 4],
          'gamma': [1e4, 'scale']}

rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=5)

rs.fit(X_train, y_train)

pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','mean_test_score']]
# Out:
#   param_C param_gamma  mean_test_score
# 0       4       10000         0.365470
# 1       1       10000         0.365470
# 2       3       10000         0.365470
# 3       2       scale         0.734763
# 4     0.1       10000         0.365470

# %%
classifier = SVC(kernel='rbf', max_iter=-1 ,decision_function_shape='ovr', tol=1e-3)
#classifier = SVC(C=4, kernel='rbf', gamma='scale', tol=1e-3, max_iter=-1, decision_function_shape='ovr')

params = {'C': [0.1, 1, 2, 3, 4],
          'gamma': ['scale']}

rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=5)

rs.fit(X_train, y_train)

pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','mean_test_score']]
# Out:
#   param_C param_gamma  mean_test_score
# 0     0.1       scale         0.605009
# 1       1       scale         0.707576
# 2       2       scale         0.734763
# 3       3       scale         0.747928
# 4       4       scale         0.756635

# %%
classifier = SVC(kernel='rbf', max_iter=-1 ,decision_function_shape='ovr', tol=1e-3)
#classifier = SVC(C=4, kernel='rbf', gamma='scale', tol=1e-3, max_iter=-1, decision_function_shape='ovr')

params = {'C': [1e1, 1e2, 1e3, 1e4, 1e5],
          'gamma': ['scale']}

rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=5)

rs.fit(X_train, y_train)

pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','mean_test_score']]
# Out:
#   param_C param_gamma  mean_test_score
# 0      10       scale         0.790612
# 1     100       scale         0.847733
# 2    1000       scale         0.877892
# 3   10000       scale         0.855807
# 4  100000       scale         0.854959

# %%
classifier = SVC(kernel='rbf', max_iter=-1 ,decision_function_shape='ovr', tol=1e-3)
#classifier = SVC(C=4, kernel='rbf', gamma='scale', tol=1e-3, max_iter=-1, decision_function_shape='ovr')

params = {'C': [1e1, 1e2, 1e3, 1e4, 1e5],
          'gamma': ['scale']}

rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=15)

rs.fit(X_train, y_train)

pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','mean_test_score']]
# Out:
#    param_C param_gamma  mean_test_score
# 0       10      0.0001         0.365470
# 1       10       scale         0.790612
# 2       10       10000         0.365470
# 3      100      0.0001         0.365470
# 4      100       scale         0.847733
# 5      100       10000         0.365470
# 6     1000      0.0001         0.365470
# 7     1000       scale         0.877892
# 8     1000       10000         0.365470
# 9    10000      0.0001         0.365470
# 10   10000       scale         0.855807
# 11   10000       10000         0.365470
# 12  100000      0.0001         0.365470
# 13  100000       scale         0.854959
# 14  100000       10000         0.365470

# %%
classifier = SVC(kernel='rbf', max_iter=-1 , tol=1e-3)
#classifier = SVC(C=4, kernel='rbf', gamma='scale', tol=1e-3, max_iter=-1, decision_function_shape='ovr')

params = {'C': [1e1, 1e2, 1e3],
          'gamma': ['scale'],
          'decision_function_shape': ['ovo', 'ovr']}

rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=6)

rs.fit(X_train, y_train)

pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','param_decision_function_shape','mean_test_score']]
# Out:
#   param_C param_gamma param_decision_function_shape  mean_test_score
# 0      10       scale                           ovo         0.790612
# 1      10       scale                           ovr         0.790612
# 2     100       scale                           ovo         0.847733
# 3     100       scale                           ovr         0.847733
# 4    1000       scale                           ovo         0.877892
# 5    1000       scale                           ovr         0.877892

# %%
classifier = SVC(kernel='rbf', max_iter=-1 , tol=1e-3)
#classifier = SVC(C=4, kernel='rbf', gamma='scale', tol=1e-3, max_iter=-1, decision_function_shape='ovr')

params = {'C': [1e1, 1e2, 1e3],
          'gamma': ['scale'],
          'decision_function_shape': ['ovr'],
          'tol': [1e-5, 1e-2, 1, 1e2, 1e5]}

rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=15)

rs.fit(X_train, y_train)

pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','param_decision_function_shape','param_tol','mean_test_score']]
# Out:
#    param_C param_gamma param_decision_function_shape param_tol  \
# 0       10       scale                           ovr     1e-05
# 1       10       scale                           ovr      0.01
# 2       10       scale                           ovr         1
# 3       10       scale                           ovr       100
# 4       10       scale                           ovr    100000
# 5      100       scale                           ovr     1e-05
# 6      100       scale                           ovr      0.01
# 7      100       scale                           ovr         1
# 8      100       scale                           ovr       100
# 9      100       scale                           ovr    100000
# 10    1000       scale                           ovr     1e-05
# 11    1000       scale                           ovr      0.01
# 12    1000       scale                           ovr         1
# 13    1000       scale                           ovr       100
# 14    1000       scale                           ovr    100000
#
#     mean_test_score
# 0          0.790612
# 1          0.790399
# 2          0.787850
# 3          0.270121
# 4          0.270121
# 5          0.847733
# 6          0.848158
# 7          0.847734
# 8          0.270121
# 9          0.270121
# 10         0.877892
# 11         0.877892
# 12         0.876829
# 13         0.270121
# 14         0.270121

# %%
classifier = SVC(kernel='rbf', max_iter=-1)

params = {'C': [1e-1 ,1 ,1e1, 1e2, 1e3],
          'gamma': ['scale'],
          'decision_function_shape': ['ovr'],
          'tol': [1e-5, 1e-2, 1]}

rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=15)

rs.fit(X_train, y_train)

pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','param_decision_function_shape','param_tol','mean_test_score']]
# Out:
#    param_C param_gamma param_decision_function_shape param_tol  \
# 0      0.1       scale                           ovr     1e-05
# 1      0.1       scale                           ovr      0.01
# 2      0.1       scale                           ovr         1
# 3        1       scale                           ovr     1e-05
# 4        1       scale                           ovr      0.01
# 5        1       scale                           ovr         1
# 6       10       scale                           ovr     1e-05
# 7       10       scale                           ovr      0.01
# 8       10       scale                           ovr         1
# 9      100       scale                           ovr     1e-05
# 10     100       scale                           ovr      0.01
# 11     100       scale                           ovr         1
# 12    1000       scale                           ovr     1e-05
# 13    1000       scale                           ovr      0.01
# 14    1000       scale                           ovr         1
#
#     mean_test_score
# 0          0.605009
# 1          0.605435
# 2          0.607559
# 3          0.707789
# 4          0.707576
# 5          0.701635
# 6          0.790612
# 7          0.790399
# 8          0.787850
# 9          0.847733
# 10         0.848158
# 11         0.847734
# 12         0.877892
# 13         0.877892
# 14         0.876829

# %%
classifier = SVC(kernel='rbf', max_iter=-1)

params = {'C': [1e1, 1e2, 1e3, 1e4],
          'gamma': ['scale'],
          'decision_function_shape': ['ovr'],
          'tol': [1e-5, 1e-2, 1]}

rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=15)

rs.fit(X_train, y_train)

pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','param_decision_function_shape','param_tol','mean_test_score']]
# Out:
# D:\Programas\anaconda3\envs\BCIMusical\lib\site-packages\sklearn\model_selection\_search.py:281: UserWarning: The total space of parameters 12 is smaller than n_iter=15. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
#    param_C param_gamma param_decision_function_shape param_tol  \
# 0       10       scale                           ovr     1e-05
# 1       10       scale                           ovr      0.01
# 2       10       scale                           ovr         1
# 3      100       scale                           ovr     1e-05
# 4      100       scale                           ovr      0.01
# 5      100       scale                           ovr         1
# 6     1000       scale                           ovr     1e-05
# 7     1000       scale                           ovr      0.01
# 8     1000       scale                           ovr         1
# 9    10000       scale                           ovr     1e-05
# 10   10000       scale                           ovr      0.01
# 11   10000       scale                           ovr         1
#
#     mean_test_score
# 0          0.790612
# 1          0.790399
# 2          0.787850
# 3          0.847733
# 4          0.848158
# 5          0.847734
# 6          0.877892
# 7          0.877892
# 8          0.876829
# 9          0.855807
# 10         0.855807
# 11         0.861116

# %%
classifier = SVC(kernel='rbf', max_iter=-1)

params = {'C': [5e2, 5e3],
          'gamma': ['scale'],
          'decision_function_shape': ['ovr'],
          'tol': [1e-5, 1e-2, 1]}

rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=6)

rs.fit(X_train, y_train)

pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','param_decision_function_shape','param_tol','mean_test_score']]
# Out:
#   param_C param_gamma param_decision_function_shape param_tol  mean_test_score
# 0     500       scale                           ovr     1e-05         0.874918
# 1     500       scale                           ovr      0.01         0.874918
# 2     500       scale                           ovr         1         0.874921
# 3    5000       scale                           ovr     1e-05         0.860053
# 4    5000       scale                           ovr      0.01         0.859840
# 5    5000       scale                           ovr         1         0.860691

# %%
classifier = SVC(kernel='rbf', max_iter=-1)
c_param = []
j = 0
for i in range (100):
    c_param.append(j)
    j += 50

params = {'C': c_param,
          'gamma': ['scale'],
          'decision_function_shape': ['ovr'],
          'tol': [1e-3]}
rs = RandomizedSearchCV(classifier, params, cv=8, scoring='accuracy', n_iter=100)
rs.fit(X_train, y_train)
pd.DataFrame(rs.cv_results_)[['param_C','param_gamma','param_decision_function_shape','param_tol','mean_test_score']]
